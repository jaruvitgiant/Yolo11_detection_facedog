# %%
from ultralytics import YOLO

# โหลดโมเดล
model = YOLO("../yolo11n.pt")  # หรือ yolov8n.pt

# Train โดยใช้ hyp_11k.yaml
model.train(
    data="../DogDatasets/data.yaml",
    epochs=100,
    imgsz=224,
    batch=16,
    hyp="hyp.yaml",
    name="results_yolov11n_aug"
)
# Out:
# Running cells with 'projectyolo11 (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/projectYOLO11/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
